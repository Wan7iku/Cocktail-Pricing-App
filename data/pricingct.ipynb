# %% [markdown]
# Import pandas library

# %%
import pandas as pd

# %% [markdown]
# load ingrdient file with utf8 format

# %%
ingredients = pd.read_csv('Ingredients_Utf8.csv')


print(ingredients.head())
# Out:
#    ingredient_id category subcategory     ingredient_name  bottle_size_ml  \
# 0              1   Liqour     Tequila    Jose Cuervo Gold          1000.0
# 1              2   Liqour     Tequila    Jose Cuervo Gold           750.0
# 2              3   Liqour     Tequila  Jose Cuervo Silver          1000.0
# 3              4   Liqour     Tequila  Jose Cuervo Silver           750.0
# 4              5   Liqour     Tequila         Olmeca Gold           750.0
#
#    bottle_cost  cost_per_ml
# 0       4000.0     4.000000
# 1       3500.0     4.666667
# 2       4000.0     4.000000
# 3       3500.0     4.666667
# 4       4000.0     5.333333

# %% [markdown]
# load recipe file

# %%
import pandas as pd
recipes = pd.read_csv('recipes.csv')
print(recipes.head())
# Out:
#   Cocktail_id cocktail_name  ingredient_id   ingredient_name  quantity
# 0       v01sb    Sea Breeze             56      Sminorff Red      60.0
# 1       v01sb    Sea Breeze            202  Grapefruit juice      30.0
# 2       v01sb    Sea Breeze            203   Cranberry juice      60.0
# 3       v01sb    Sea Breeze            215       Sugar syrup      15.0
# 4       v01sb    Sea Breeze            229         Ice-cubed     100.0

# %%
ingredientcost= recipes.quantity * ingredients.cost_per_ml
print(ingredientcost.head())
# Out:
# 0    240.000000
# 1    140.000000
# 2    240.000000
# 3     70.000000
# 4    533.333333
# dtype: float64

# %% [markdown]
# show data types so that merge can happen smoothly

# %%
print(recipes.dtypes)
print(ingredients.dtypes)
# Out:
# Cocktail_id            str
# cocktail_name          str
# ingredient_id        int64
# ingredient_name        str
# quantity           float64
# dtype: object
# ingredient_id        int64
# category               str
# subcategory            str
# ingredient_name        str
# bottle_size_ml     float64
# bottle_cost        float64
# cost_per_ml        float64
# dtype: object

# %%
recipes["ingredient_id"] = recipes["ingredient_id"].astype(str)
ingredients["ingredient_id"] = ingredients["ingredient_id"].astype(str)

# %% [markdown]
# merging with cocktail_id as string data type

# %%
cocktails = recipes.merge(
    ingredients,
    on="ingredient_id",
    how="left"
)

# %%
print(cocktails.head())
# Out:
#   Cocktail_id cocktail_name  ingredient_id ingredient_name_x  quantity  \
# 0       v01sb    Sea Breeze             56      Sminorff Red      60.0
# 1       v01sb    Sea Breeze            202  Grapefruit juice      30.0
# 2       v01sb    Sea Breeze            203   Cranberry juice      60.0
# 3       v01sb    Sea Breeze            215       Sugar syrup      15.0
# 4       v01sb    Sea Breeze            229         Ice-cubed     100.0
#
#   category subcategory ingredient_name_y  bottle_size_ml  bottle_cost  \
# 0   Liqour       Vodka     Sminorff Red           1000.0       2500.0
# 1    Mixer       Juice  Grapefruit juice          1000.0        400.0
# 2    Mixer       Juice   Cranberry juice          1000.0        300.0
# 3    Mixer       Syrup       Sugar syrup          1000.0        300.0
# 4      Ice         Ice         Ice cubed          1000.0         50.0
#
#    cost_per_ml
# 0         2.50
# 1         0.40
# 2         0.30
# 3         0.30
# 4         0.05

# %%
cocktails["ingredient_cost"] = (
    cocktails["quantity"] *
    cocktails["cost_per_ml"]
)

# %%
cocktail_costs = (
    cocktails.groupby(
        ["Cocktail_id", "cocktail_name"]
    )["ingredient_cost"]
    .sum()
    .reset_index()
)

# %%
print(cocktails.columns.tolist())
# Out:
# ['Cocktail_id', 'cocktail_name', 'ingredient_id', 'ingredient_name_x', 'quantity', 'category', 'subcategory', 'ingredient_name_y', 'bottle_size_ml', 'bottle_cost', 'cost_per_ml', 'ingredient_cost']

# %%
cocktail_costs.rename(
    columns={"ingredient_cost": "total_cost"},
    inplace=True
)

# %%
print(cocktail_costs.head())
# Out:
#   Cocktail_id     cocktail_name   total_cost
# 0       b01sc          Side car   231.250000
# 1       b02ba  Brandy Alexander   239.100000
# 2       b03sa           Sangria  6303.516667
# 3       b04bb               B&B   242.000000
# 4       b05bs    Brandy stinger   219.000000

# %%
cocktail_costs.to_csv(
    "cocktail_prices.csv",
    index=False
)

print(cocktail_costs.head())
# Out:
#   Cocktail_id     cocktail_name   total_cost
# 0       b01sc          Side car   231.250000
# 1       b02ba  Brandy Alexander   239.100000
# 2       b03sa           Sangria  6303.516667
# 3       b04bb               B&B   242.000000
# 4       b05bs    Brandy stinger   219.000000

# %%
def calculate_selling_price(total_cost):
    return total_cost * 4

# %%
total_cost = cocktail_costs["total_cost"]
spillage_pct = 0.05      # 5%
target_gp_pct = 0.75     # 75% GP
vat_pct = 0.16     # 16% VAT

# Adjust cost for wastage/spillage
adjusted_cost = total_cost * (1 + spillage_pct)

# Calculate selling price before VAT
selling_price_ex_vat = adjusted_cost / (1 - target_gp_pct)

# Add VAT
final_price = selling_price_ex_vat * (1 + vat_pct)

# %%
print (cocktail_costs.cocktail_name, round(final_price, 2))
# Out:
# 0                   Side car
# 1           Brandy Alexander
# 2                    Sangria
# 3                        B&B
# 4             Brandy stinger
# 5          French connection
# 6             Cherry Blossom
# 7                 Black jack
# 8              Brandy cooler
# 9         Between the sheets
# 10           Classic Martini
# 11                  Gin Fizz
# 12                   Bramble
# 13           Singapore Sling
# 14                 Pink lady
# 15                     Bronx
# 16               French Kiss
# 17                White lady
# 18            Honolulu punch
# 19                   Negroni
# 20             Pimms cup no1
# 21                Caipirinha
# 22                Cuba libre
# 23          Classic_Daiquiri
# 24                   Mai_tai
# 25                pinacolada
# 26            Planters punch
# 27                   Barcadi
# 28                    Mojito
# 29                    Zombie
# 30      Long Island Iced Tea
# 31                 Hurricane
# 32                    Rumble
# 33                 Margarita
# 34           Tequila sunrise
# 35                 El Diablo
# 36               ice breaker
# 37                  Acapulco
# 38                Sea Breeze
# 39             Black Russian
# 40              Cosmopolitan
# 41         Harvey Wallbanger
# 42         Sex on the beach
# 43               Moscow Mule
# 44               Caipirosvka
# 45                  Kamikaze
# 46               Bloody Mary
# 47    Slow Comfortable Screw
# 48        Lynchburg lemonade
# 49                 Manhattan
# 50                Mint Julep
# 51             Old Fashioned
# 52                Rusty Nail
# 53               Whisky sour
# 54              Irish coffee
# 55                 Godfather
# 56                 Hemingway
# 57                   Rob roy
# Name: cocktail_name, dtype: str 0      1126.65
# 1      1164.90
# 2     30710.73
# 3      1179.02
# 4      1066.97
# 5      1433.76
# 6      1241.14
# 7      1104.48
# 8      1125.68
# 9      1376.34
# 10      755.16
# 11      880.45
# 12      912.12
# 13     1162.05
# 14      690.61
# 15      818.01
# 16     1177.98
# 17      974.40
# 18      821.50
# 19     1641.86
# 20     1410.20
# 21     1478.16
# 22     1059.90
# 23      828.24
# 24     1155.88
# 25     1052.35
# 26      748.58
# 27      841.64
# 28     1264.53
# 29     1520.06
# 30     1315.68
# 31      836.77
# 32      626.90
# 33     1666.22
# 34     1825.05
# 35     1878.05
# 36     1775.84
# 37     1766.91
# 38     3968.24
# 39      893.85
# 40      976.84
# 41     2305.78
# 42     1151.74
# 43      876.96
# 44      856.69
# 45     1148.57
# 46     1233.10
# 47     1244.39
# 48     1650.63
# 49     1784.21
# 50     1226.77
# 51     1367.08
# 52     1343.45
# 53     1510.97
# 54     1903.73
# 55      711.31
# 56      971.39
# 57      924.30
# Name: total_cost, dtype: float64

# %%
import pandas as pd

# Load  existing cocktail cost file
df = pd.read_csv("cocktail_prices.csv")

# Parameters
SPILLAGE_PCT = 0.05   # 5%
TARGET_GP_PCT = 0.65  # 65%
VAT_PCT = 0.16        # 16%

# Calculations
df["cost_after_spillage"] = df["total_cost"] * (1 + SPILLAGE_PCT)

df["selling_price_before_vat"] = (
    df["cost_after_spillage"] / (1 - TARGET_GP_PCT)
)

df["selling_price_after_vat"] = (
    df["selling_price_before_vat"] * (1 + VAT_PCT)
)

# Round to 2 decimal places
cols_to_round = [
    "total_cost",
    "cost_after_spillage",
    "selling_price_before_vat",
    "selling_price_after_vat"
]

df[cols_to_round] = df[cols_to_round].round(2)

# Save new CSV
df.to_csv("cocktail_final_prices.csv", index=False)

print(df.head())
# Out:
#   Cocktail_id     cocktail_name  total_cost  cost_after_spillage  \
# 0       b01sc          Side car      231.25               242.81
# 1       b02ba  Brandy Alexander      239.10               251.05
# 2       b03sa           Sangria     6303.52              6618.69
# 3       b04bb               B&B      242.00               254.10
# 4       b05bs    Brandy stinger      219.00               229.95
#
#    selling_price_before_vat  selling_price_after_vat
# 0                    693.75                   804.75
# 1                    717.30                   832.07
# 2                  18910.55                 21936.24
# 3                    726.00                   842.16
# 4                    657.00                   762.12

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.58.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (6.2.1)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (3.1.50)
# Requirement already satisfied: numpy<3,>=1.23 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (2.4.6)
# Requirement already satisfied: packaging>=20 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (3.0.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (12.2.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (7.35.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn>=0.30.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (0.49.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (4.13.0)
# Requirement already satisfied: python-multipart>=0.0.10 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets>=12.0.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.22.1)
# Requirement already satisfied: colorama in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.5.20)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.5.1)
# Requirement already satisfied: six>=1.5 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import streamlit as st
import pandas as pd

# Load the final pricing data

df = pd.read_csv("data/cocktail_final_prices.csv")

st.title("🍸 Cocktail Pricing Engine")

cocktail = st.selectbox(
    "Choose Cocktail",
    df["cocktail_name"]
)

selected = df[df["cocktail_name"] == cocktail]

st.dataframe(selected)

st.subheader(
    "Cocktail Profitability Ranking"
)

ranking = (
    df[
        [
            "cocktail_name",
            "cost_after_spillage",
            "selling_price_after_vat",
            "profit",
            "gp_percent"
        ]
    ]
    .sort_values(
        "profit",
        ascending=False
    )
)

st.dataframe(
    ranking,
    use_container_width=True
)
# Out:
# 2026-06-17 12:46:28.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 12:46:28.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 12:46:28.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 12:46:28.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 12:46:28.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 12:46:28.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import streamlit as st

st.title("🍸 Cocktail Pricing Engine")

st.write("If you can see this, Streamlit is working.")
# Out:
# 2026-06-17 13:42:18.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:42:18.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:42:18.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:42:19.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:42:19.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-17 13:42:19.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
pip install plotly
# Out:
# Collecting plotly
#   Using cached plotly-6.8.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: narwhals>=1.15.1 in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from plotly) (2.22.1)
# Requirement already satisfied: packaging in c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from plotly) (26.2)
# Using cached plotly-6.8.0-py3-none-any.whl (9.9 MB)
# Installing collected packages: plotly
# Successfully installed plotly-6.8.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
#   WARNING: The script plotly_get_chrome.exe is installed in 'c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
